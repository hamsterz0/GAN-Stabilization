# %%
# !rm -rf GAN-Stabilization/

# !git clone https://github.com/thearnavgarg/GAN-Stabilization.git
# Out:
# Cloning into 'GAN-Stabilization'...
# remote: Enumerating objects: 112, done.
# remote: Counting objects: 100% (112/112), done.
# remote: Compressing objects: 100% (83/83), done.
# remote: Total 112 (delta 59), reused 75 (delta 28), pack-reused 0
# Receiving objects: 100% (112/112), 40.94 MiB | 25.75 MiB/s, done.
# Resolving deltas: 100% (59/59), done.

# %%
# !unzip '/content/GAN-Stabilization/fid_data.zip' -d '/content/GAN-Stabilization/'
# Out:
# Archive:  /content/GAN-Stabilization/fid_data.zip
#    creating: /content/GAN-Stabilization/fid_data/
#   inflating: /content/GAN-Stabilization/fid_data/49897_ship.png
#   inflating: /content/GAN-Stabilization/fid_data/16978_ship.png
#   inflating: /content/GAN-Stabilization/fid_data/248_frog.png
#   inflating: /content/GAN-Stabilization/fid_data/31839_horse.png
#   inflating: /content/GAN-Stabilization/fid_data/23494_dog.png
#   inflating: /content/GAN-Stabilization/fid_data/7082_dog.png
#   inflating: /content/GAN-Stabilization/fid_data/6166_automobile.png
#   inflating: /content/GAN-Stabilization/fid_data/15413_horse.png
#   inflating: /content/GAN-Stabilization/fid_data/41525_automobile.png
#   inflating: /content/GAN-Stabilization/fid_data/28188_frog.png
#   inflating: /content/GAN-Stabilization/fid_data/33604_frog.png
#   inflating: /content/GAN-Stabilization/fid_data/18575_dog.png
#   inflating: /content/GAN-Stabilization/fid_data/4228_bird.png
# ...

# %%
# !unzip '/content/GAN-Stabilization/generated_data.zip' -d '/content/GAN-Stabilization/'
# Out:
# Archive:  /content/GAN-Stabilization/generated_data.zip
#    creating: /content/GAN-Stabilization/generated_data/
#   inflating: /content/GAN-Stabilization/generated_data/image_4877.png
#   inflating: /content/GAN-Stabilization/generated_data/image_408.png
#   inflating: /content/GAN-Stabilization/generated_data/image_4863.png
#   inflating: /content/GAN-Stabilization/generated_data/image_1933.png
#   inflating: /content/GAN-Stabilization/generated_data/image_4693.png
#   inflating: /content/GAN-Stabilization/generated_data/image_420.png
#   inflating: /content/GAN-Stabilization/generated_data/image_2584.png
#   inflating: /content/GAN-Stabilization/generated_data/image_346.png
#   inflating: /content/GAN-Stabilization/generated_data/image_3842.png
#   inflating: /content/GAN-Stabilization/generated_data/image_1099.png
#   inflating: /content/GAN-Stabilization/generated_data/image_2590.png
#   inflating: /content/GAN-Stabilization/generated_data/image_352.png
# ...

# %%
# !python GAN-Stabilization/fid.py /content/GAN-Stabilization/generated_data/ /content/GAN-Stabilization/fid_data/ --gpu 0
# Out:
# ...
# WARNING:tensorflow:From GAN-Stabilization/fid.py:37: FastGFile.__init__ (from tensorflow.python.platform.gfile) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.gfile.GFile.
# 2019-03-19 09:08:26.618677: W tensorflow/core/framework/op_def_util.cc:355] Op BatchNormWithGlobalNormalization is deprecated. It will cease to work in GraphDef version 9. Use tf.nn.batch_normalization().
# 2019-03-19 09:08:26.853402: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2300000000 Hz
# 2019-03-19 09:08:26.854122: I tensorflow/compiler/xla/service/service.cc:150] XLA service 0x2e6b4a0 executing computations on platform Host. Devices:
# 2019-03-19 09:08:26.854222: I tensorflow/compiler/xla/service/service.cc:158]   StreamExecutor device (0): <undefined>, <undefined>
# ...

# %%
# !python GAN-Stabilization/fid_score.py /content/GAN-Stabilization/generated_data/ /content/GAN-Stabilization/fid_data/ --gpu 0
# Out:
#  75% 75/100 [00:40<00:13,  1.87it/s]
